# %%
# echo "# github-practice" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/Navaraj70059/github-practice.git
# git push -u origin main

# %% [markdown]
# Recommended Commit Types
# Use these prefixes to categorize your changes:
# feat: A new feature for the user.
# fix: A bug fix.
# docs: Changes only to documentation (README, comments, docstrings).
# style: Formatting changes that do not affect code meaning (indentation, whitespace, semi-colons).
# refactor: Code changes that neither fix a bug nor add a feature (restructuring).
# perf: Code changes aimed at improving performance.
# test: Adding missing tests or correcting existing tests.
# chore: Maintenance tasks like updating dependencies or build scripts that don't modify source files.
# build: Changes affecting the build system or external dependencies (e.g., npm, webpack).
# ci: Changes to CI configuration files and scripts (e.g., GitHub Actions, GitLab CI).
